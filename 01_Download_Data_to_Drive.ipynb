# %% [markdown]
# Mount Your Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Install the Kaggle API and Upload Your Kaggle API Token

# %%
# !pip install kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-a0ceaf51-0842-46c2-84b6-2d82847c9fea" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a0ceaf51-0842-46c2-84b6-2d82847c9fea">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# Download the Dataset to Google Drive

# %%
# Make sure you have already run the cell defining this variable
DRIVE_DOWNLOAD_PATH = "/content/drive/My Drive/Final Year Project/Data"

# Now run the corrected download command
# !kaggle datasets download -d risangbaskoro/wlasl-processed -p "{DRIVE_DOWNLOAD_PATH}"
# Out:
# Dataset URL: https://www.kaggle.com/datasets/risangbaskoro/wlasl-processed
# License(s): other
# wlasl-processed.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip "{DRIVE_DOWNLOAD_PATH}/wlasl-processed.zip" -d "{DRIVE_DOWNLOAD_PATH}/"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/My Drive/Final Year Project/Data/videos/43596.mp4
#   inflating: /content/drive/My Drive/Final Year Project/Data/videos/43598.mp4
#   inflating: /content/drive/My Drive/Final Year Project/Data/videos/43599.mp4
#   inflating: /content/drive/My Drive/Final Year Project/Data/videos/43671.mp4
#   inflating: /content/drive/My Drive/Final Year Project/Data/videos/43672.mp4
#   inflating: /content/drive/My Drive/Final Year Project/Data/videos/43674.mp4
#   inflating: /content/drive/My Drive/Final Year Project/Data/videos/43677.mp4
#   inflating: /content/drive/My Drive/Final Year Project/Data/videos/43679.mp4
#   inflating: /content/drive/My Drive/Final Year Project/Data/videos/43680.mp4
#   inflating: /content/drive/My Drive/Final Year Project/Data/videos/43681.mp4
#   inflating: /content/drive/My Drive/Final Year Project/Data/videos/43682.mp4
# ...
